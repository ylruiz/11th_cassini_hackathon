# %% [markdown]
# # CDS Hydrology Forecast Dataset: Download and Plot
#
# Dataset: `sis-hydrology-variables-derived-seasonal-forecast`
#
# This notebook:
# - downloads one subset from CDS via `cdsapi`
# - opens the NetCDF with `xarray`
# - plots a map and a point time series
#
# If the request fails due to parameter mismatch, copy the exact API request from the CDS **Download** tab and paste it in the request cell below.

# %%
from __future__ import annotations

from pathlib import Path
import os
import zipfile

import matplotlib
matplotlib.use("Agg", force=True)
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

# %matplotlib inline

import cdsapi

matplotlib.rcParams["text.usetex"] = False
matplotlib.rcParams["font.family"] = "sans-serif"
matplotlib.rcParams["font.sans-serif"] = ["DejaVu Sans", "Liberation Sans", "Arial"]
matplotlib.rcParams["mathtext.fontset"] = "dejavusans"

def find_project_root(start: Path) -> Path:
    p = start.resolve()
    for candidate in [p] + list(p.parents):
        if (candidate / "data").exists() and (candidate / "src").exists():
            return candidate
    return p

ROOT = find_project_root(Path.cwd())
DATA_DIR = ROOT / "data" / "cds"
FIG_DIR = ROOT / "figures"
DATA_DIR.mkdir(parents=True, exist_ok=True)
FIG_DIR.mkdir(parents=True, exist_ok=True)

print(f"ROOT: {ROOT}")


def resolve_cdsapirc(root: Path) -> Path | None:
    candidates = [
        root / '.cdsapirc',
        Path.cwd() / '.cdsapirc',
        Path.home() / '.cdsapirc',
    ]
    for c in candidates:
        if c.exists():
            return c
    return None

CDSAPI_RC_PATH = resolve_cdsapirc(ROOT)
if CDSAPI_RC_PATH is not None:
    os.environ['CDSAPI_RC'] = str(CDSAPI_RC_PATH)


print(f"CDSAPI_RC selected: {CDSAPI_RC_PATH}")
# Out:
# ROOT: /home/vsilv/.nextcloud/src/cassini/11th_cassini_hackathon/python_analysis
# CDSAPI_RC selected: /home/vsilv/.nextcloud/src/cassini/11th_cassini_hackathon/python_analysis/.cdsapirc

# %% [markdown]
# ## Request parameters
#
# The default request below is a **starter template**.
# If CDS rejects it, replace `REQUEST` with the exact script from the CDS Download tab.

# %%
DATASET_ID = "sis-hydrology-variables-derived-seasonal-forecast"
TARGET_FILE = DATA_DIR / "cds_hydrology_forecast_subset.zip"
NETCDF_FILE = DATA_DIR / "cds_hydrology_forecast_subset.nc"
FORCE_DOWNLOAD = False

# Valid minimal request (adjust after first successful run)
REQUEST = {
    "variable": ["river_discharge"],
    "hydrological_model": ["lisflood_efas"],
    "year": ["2024"],
    "month": ["01"],
    "version": ["1"],
}

print(f"Dataset: {DATASET_ID}")
print(f"Target archive: {TARGET_FILE}")
print(f"Preferred NetCDF path: {NETCDF_FILE}")
print("Request keys:", list(REQUEST.keys()))
# Out:
# Dataset: sis-hydrology-variables-derived-seasonal-forecast
# Target file: /home/vsilv/.nextcloud/src/cassini/11th_cassini_hackathon/python_analysis/data/cds/cds_hydrology_forecast_subset.nc

# %%
if (TARGET_FILE.exists() or NETCDF_FILE.exists()) and not FORCE_DOWNLOAD:
    print(f"Using existing data in {DATA_DIR}")
else:
    if CDSAPI_RC_PATH is None:
        raise RuntimeError("Missing .cdsapirc. Put it in project root or home directory.")

    print("Submitting CDS request...")
    client = cdsapi.Client()
    try:
        client.retrieve(DATASET_ID, REQUEST, str(TARGET_FILE))
        print(f"Download complete: {TARGET_FILE}")
    except Exception as exc:
        msg = str(exc)
        if "required licences not accepted" in msg.lower():
            raise RuntimeError(
                "CDS account is authenticated but dataset licence is not accepted yet.\n"
                "Open the dataset page and accept licences:\n"
                "https://cds.climate.copernicus.eu/datasets/sis-hydrology-variables-derived-seasonal-forecast?tab=download#manage-licences"
            )
        raise RuntimeError(
            "CDS request failed. If parameters changed, copy the exact API request from CDS Download tab into REQUEST.\n"
            f"Original error: {exc}"
        )

if zipfile.is_zipfile(TARGET_FILE):
    with zipfile.ZipFile(TARGET_FILE) as zf:
        members = [name for name in zf.namelist() if name.endswith(".nc")]
        if not members:
            raise RuntimeError(f"Downloaded ZIP contains no NetCDF files: {TARGET_FILE}")
        zf.extract(members[0], path=DATA_DIR)
        extracted = DATA_DIR / members[0]
        DS_FILE = DATA_DIR / Path(members[0]).name
        if extracted != DS_FILE:
            extracted.replace(DS_FILE)
else:
    DS_FILE = NETCDF_FILE if NETCDF_FILE.exists() else TARGET_FILE

print(f"Dataset file for xarray: {DS_FILE}")
# Out:
# Submitting CDS request...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 13
#      11         print(f"Download complete: {TARGET_FILE}")
#      12     except Exception as exc:
# ---> 13         raise RuntimeError(
#      14             "CDS request failed. Paste the exact API request from the CDS Download tab into REQUEST.\n"
#
# File ~/.local/share/pipx/venvs/openeo/lib/python3.14/site-packages/ecmwf/datastores/legacy_client.py:167, in LegacyClient.retrieve(self, name, request, target)
#     166 if self.wait_until_complete:
# --> 167     submitted = self.client.submit_and_wait_on_results(
#     168         collection_id=name,
#     169         request=request,
#     170     )
#     171 else:
#
# File ~/.local/share/pipx/venvs/openeo/lib/python3.14/site-packages/ecmwf/datastores/client.py:430, in Client.submit_and_wait_on_results(self, collection_id, request)
#     417 """Submit a request and wait for the results to be ready.
#     418
#     419 Parameters
#    (...)    428 datastores.Results
#     429 """
# --> 430 return self._retrieve_api.submit(collection_id, request).get_results()
#
# File ~/.local/share/pipx/venvs/openeo/lib/python3.14/site-packages/ecmwf/datastores/processing.py:753, in Processing.submit(self, collection_id, request)
#     752 def submit(self, collection_id: str, request: dict[str, Any]) -> Remote:
# --> 753     return self.get_process(collection_id).submit(request)
#
# File ~/.local/share/pipx/venvs/openeo/lib/python3.14/site-packages/ecmwf/datastores/processing.py:316, in Process.submit(self, request)
#     305 """Submit a request.
#     306
#     307 Parameters
#    (...)    314 datastores.Remote
#     315 """
# --> 316 job = Job.from_request(
#     317     "post",
#     318     f"{self.url}/execution",
#     319     json={"inputs": request},
#     320     **self._request_kwargs,
#     321 )
#     322 return job.get_remote()
#
# File ~/.local/share/pipx/venvs/openeo/lib/python3.14/site-packages/ecmwf/datastores/processing.py:176, in ApiResponse.from_request(cls, method, url, headers, session, retry_options, request_options, download_options, sleep_max, cleanup, log_callback, log_messages, **kwargs)
#     174 log(logging.DEBUG, f"REPLY {response.text}", callback=log_callback)
# --> 176 cads_raise_for_status(response)
#     178 self = cls(
#     179     response,
#     180     headers=headers,
#    (...)    187     log_callback=log_callback,
#     188 )
#
# File ~/.local/share/pipx/venvs/openeo/lib/python3.14/site-packages/ecmwf/datastores/processing.py:99, in cads_raise_for_status(response)
#      93         message = "\n".join(
#      94             [
#      95                 f"{response.status_code} Client Error: {response.reason} for url: {response.url}",
#      96                 error_json_to_message(error_json),
#      97             ]
#      98         )
# ---> 99         raise requests.HTTPError(message, response=response)
#     100 response.raise_for_status()
#
# HTTPError: 400 Client Error: Bad Request for url: https://cds.climate.copernicus.eu/api/retrieve/v1/processes/sis-hydrology-variables-derived-seasonal-forecast/execution
# invalid request
# Request has not produced a valid combination of values, please check your selection.
# {'hydrological_model': 'efas', 'leadtime_month': ['1', '2', '3', '4', '5', '6', '7'], 'month': ['01', '02', '03'], 'originating_centre': 'ecmwf', 'system': '5', 'variable': 'river_discharge', 'year': ['2024']}
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 13
#       9     try:
#      10         client.retrieve(DATASET_ID, REQUEST, str(TARGET_FILE))
#      11         print(f"Download complete: {TARGET_FILE}")
#      12     except Exception as exc:
# ---> 13         raise RuntimeError(
#      14             "CDS request failed. Paste the exact API request from the CDS Download tab into REQUEST.\n"
#      15             f"Original error: {exc}"
#      16         )
#
# RuntimeError: CDS request failed. Paste the exact API request from the CDS Download tab into REQUEST.
# Original error: 400 Client Error: Bad Request for url: https://cds.climate.copernicus.eu/api/retrieve/v1/processes/sis-hydrology-variables-derived-seasonal-forecast/execution
# invalid request
# Request has not produced a valid combination of values, please check your selection.
# {'hydrological_model': 'efas', 'leadtime_month': ['1', '2', '3', '4', '5', '6', '7'], 'month': ['01', '02', '03'], 'originating_centre': 'ecmwf', 'system': '5', 'variable': 'river_discharge', 'year': ['2024']}

# %%
ds = xr.open_dataset(DS_FILE, engine="netcdf4")
print(ds)
print("\nVariables:", list(ds.data_vars))

# %%
# Plot config
PLOT_VARIABLE = "rdis"  # default variable for this dataset
POINT_LAT = 46.8
POINT_LON = 11.3

y_name = next((c for c in ["y", "lat", "latitude"] if c in ds.dims), None)
x_name = next((c for c in ["x", "lon", "longitude"] if c in ds.dims), None)
if y_name is None or x_name is None:
    raise RuntimeError(f"Could not detect spatial dimensions. Found dims={list(ds.dims)}")

lat_coord = "latitude" if "latitude" in ds.coords else ("lat" if "lat" in ds.coords else y_name)
lon_coord = "longitude" if "longitude" in ds.coords else ("lon" if "lon" in ds.coords else x_name)

if PLOT_VARIABLE not in ds.data_vars:
    PLOT_VARIABLE = None
if PLOT_VARIABLE is None:
    for name, da in ds.data_vars.items():
        if y_name in da.dims and x_name in da.dims:
            PLOT_VARIABLE = name
            break
if PLOT_VARIABLE is None:
    raise RuntimeError("No plottable geospatial variable found. Set PLOT_VARIABLE manually.")

da = ds[PLOT_VARIABLE]
print(f"Using variable: {PLOT_VARIABLE} dims={da.dims}")

indexers = {d: 0 for d in da.dims if d not in [y_name, x_name]}
da_map = da.isel(indexers) if indexers else da

fig, ax = plt.subplots(figsize=(8, 5))
if lat_coord in ds.coords and lon_coord in ds.coords and ds[lat_coord].ndim == 2 and ds[lon_coord].ndim == 2:
    im = ax.pcolormesh(ds[lon_coord], ds[lat_coord], da_map, shading="auto", cmap="viridis")
    ax.set_xlabel("longitude")
    ax.set_ylabel("latitude")
else:
    im = ax.pcolormesh(ds[x_name], ds[y_name], da_map, shading="auto", cmap="viridis")
    ax.set_xlabel(x_name)
    ax.set_ylabel(y_name)
ax.set_title(f"{PLOT_VARIABLE} (first slice)")
fig.colorbar(im, ax=ax, shrink=0.85)
plt.tight_layout()
plt.show()

# %%
# Time series at nearest point
if lat_coord in ds.coords and lon_coord in ds.coords and ds[lat_coord].ndim == 2 and ds[lon_coord].ndim == 2:
    dist2 = (ds[lat_coord] - POINT_LAT) ** 2 + (ds[lon_coord] - POINT_LON) ** 2
    iy, ix = np.unravel_index(np.nanargmin(dist2.values), dist2.shape)
    da_point = ds[PLOT_VARIABLE].isel({y_name: int(iy), x_name: int(ix)})
else:
    da_point = ds[PLOT_VARIABLE].sel({y_name: POINT_LAT, x_name: POINT_LON}, method="nearest")

time_candidates = ["valid_time", "time", "step", "forecast_reference_time", "t"]
time_name = next((t for t in time_candidates if t in da_point.dims or t in da_point.coords), None)
if time_name is None:
    if len(da_point.dims) == 0:
        raise RuntimeError("Point selection produced scalar only; no time axis to plot.")
    time_name = da_point.dims[0]

if time_name in da_point.dims:
    time_dim = time_name
elif time_name in da_point.coords and da_point[time_name].ndim > 0:
    time_dim = da_point[time_name].dims[0]
else:
    time_dim = da_point.dims[0]

reduce_dims = [d for d in da_point.dims if d != time_dim]
da_ts = da_point.mean(dim=reduce_dims, skipna=True) if reduce_dims else da_point

xvals = da_ts[time_name].values if time_name in da_ts.coords else da_ts[time_dim].values
fig, ax = plt.subplots(figsize=(9, 3.8))
ax.plot(xvals, da_ts.values, marker="o", linewidth=1.5)
ax.set_title(f"{PLOT_VARIABLE} at nearest point ({POINT_LAT:.2f}, {POINT_LON:.2f})")
ax.set_xlabel(time_name)
ax.set_ylabel(PLOT_VARIABLE)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()
