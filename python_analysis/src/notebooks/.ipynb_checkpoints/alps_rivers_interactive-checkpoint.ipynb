# %% [markdown]
# # Alpine Rivers NDWI (Clean Notebook)
#
# Static, reproducible workflow using openEO + Sentinel-2.
#
# - No widgets
# - No HTML map
# - `%matplotlib inline` only
# - All parameters are editable in one cell

# %%
from __future__ import annotations

from datetime import datetime
from pathlib import Path
from time import perf_counter
import hashlib
import json

import matplotlib
matplotlib.use("Agg", force=True)
import matplotlib.pyplot as plt
import numpy as np
import openeo
import xarray as xr

# %matplotlib inline

matplotlib.rcParams["text.usetex"] = False
matplotlib.rcParams["font.family"] = "sans-serif"
matplotlib.rcParams["font.sans-serif"] = ["DejaVu Sans", "Liberation Sans", "Arial"]
matplotlib.rcParams["mathtext.fontset"] = "dejavusans"

# %%
# Parameters (edit here)
WEST = 11.293602
EAST = 11.382866
SOUTH = 46.460163
NORTH = 46.514768

START_DATE = "2023-07-01"
END_DATE = "2023-07-20"

MAX_CLOUD_COVER = 20.0
NDWI_THRESHOLD = 0.10
FORCE_DOWNLOAD = False

def find_project_root(start: Path) -> Path:
    p = start.resolve()
    for candidate in [p] + list(p.parents):
        if (candidate / "data").exists() and (candidate / "src").exists():
            return candidate
    return p

ROOT = find_project_root(Path.cwd())
DATA_DIR = ROOT / "data"
FIG_DIR = ROOT / "figures"
DATA_DIR.mkdir(parents=True, exist_ok=True)
FIG_DIR.mkdir(parents=True, exist_ok=True)

print(f"ROOT: {ROOT}")
print(
    f"AOI: west={WEST}, east={EAST}, south={SOUTH}, north={NORTH} | "
    f"dates={START_DATE}..{END_DATE} | cloud<={MAX_CLOUD_COVER}% | threshold={NDWI_THRESHOLD}"
)
# Out:
# ROOT: /home/vsilv/.nextcloud/src/cassini/11th_cassini_hackathon/python_analysis
# AOI: west=11.293602, east=11.382866, south=46.460163, north=46.514768 | dates=2023-07-01..2023-07-20 | cloud<=20.0% | threshold=0.1

# %%
def validate_inputs(west: float, east: float, south: float, north: float, start: str, end: str) -> None:
    if not (west < east and south < north):
        raise ValueError("Invalid bbox: require west < east and south < north.")
    start_dt = datetime.strptime(start, "%Y-%m-%d")
    end_dt = datetime.strptime(end, "%Y-%m-%d")
    if start_dt > end_dt:
        raise ValueError("Invalid dates: start must be <= end.")

def cache_path_for_query(bbox: dict, start: str, end: str, cloud: float) -> Path:
    payload = {"bbox": bbox, "start": start, "end": end, "cloud": cloud}
    key = hashlib.md5(json.dumps(payload, sort_keys=True).encode("utf-8")).hexdigest()[:12]
    return DATA_DIR / f"alps_s2_{key}.nc"

def download_cube_if_needed(bbox: dict, start: str, end: str, cloud: float, force: bool) -> Path:
    nc_path = cache_path_for_query(bbox, start, end, cloud)
    if nc_path.exists() and not force:
        print(f"Using cache: {nc_path}")
        return nc_path

    print("Connecting to openEO backend...")
    conn = openeo.connect("openeo.dataspace.copernicus.eu").authenticate_oidc()

    print("Loading SENTINEL2_L2A (B03, B08)...")
    cube = conn.load_collection(
        "SENTINEL2_L2A",
        spatial_extent=bbox,
        temporal_extent=[start, end],
        bands=["B03", "B08"],
        max_cloud_cover=cloud,
    )

    print(f"Downloading to {nc_path} ...")
    cube.download(str(nc_path))
    print("Download done.")
    return nc_path

def compute_ndwi(nc_path: Path):
    ds = xr.open_dataset(nc_path)
    if "B03" not in ds.variables or "B08" not in ds.variables:
        raise RuntimeError("Missing B03/B08 variables in NetCDF.")

    green = ds["B03"].astype("float32")
    nir = ds["B08"].astype("float32")
    ndwi = (green - nir) / (green + nir)

    if "t" in ndwi.dims:
        ndwi2d = ndwi.median(dim="t", skipna=True)
    else:
        ndwi2d = ndwi

    arr = ndwi2d.values
    if not np.isfinite(arr).any():
        raise RuntimeError("No finite NDWI pixels. Try another AOI/date range.")

    lons = ndwi2d["x"].values.astype(float)
    lats = ndwi2d["y"].values.astype(float)
    return arr, lons, lats

def build_mask(arr: np.ndarray, threshold: float) -> np.ndarray:
    mask = np.zeros_like(arr, dtype=np.uint8)
    finite = np.isfinite(arr)
    mask[finite & (arr > threshold)] = 1
    return mask

# %%
# Run download + compute
t0 = perf_counter()

validate_inputs(WEST, EAST, SOUTH, NORTH, START_DATE, END_DATE)
bbox = {"west": WEST, "east": EAST, "south": SOUTH, "north": NORTH, "crs": "EPSG:4326"}

nc_path = download_cube_if_needed(
    bbox=bbox,
    start=START_DATE,
    end=END_DATE,
    cloud=MAX_CLOUD_COVER,
    force=FORCE_DOWNLOAD,
)

arr, lons, lats = compute_ndwi(nc_path)
mask = build_mask(arr, NDWI_THRESHOLD)

print(
    f"NDWI stats: min={np.nanmin(arr):.3f}, max={np.nanmax(arr):.3f}, mean={np.nanmean(arr):.3f}"
)
print(f"Finite pixels: {np.isfinite(arr).sum()} | Water pixels: {mask.sum()}")
print(f"Elapsed: {perf_counter() - t0:.2f}s")
# Out:
# Using cache: /home/vsilv/.nextcloud/src/cassini/11th_cassini_hackathon/python_analysis/data/alps_s2_b90427a09844.nc
# NDWI stats: min=-1.109, max=0.692, mean=-0.597
# Finite pixels: 442112 | Water pixels: 5014
# Elapsed: 0.07s

# %%
# Plot NDWI, water mask, and histogram
origin = "upper" if lats[0] > lats[-1] else "lower"
extent = [float(lons.min()), float(lons.max()), float(lats.min()), float(lats.max())]

fig, (ax_ndwi, ax_mask, ax_hist) = plt.subplots(1, 3, figsize=(14, 5))

im = ax_ndwi.imshow(arr, cmap="RdBu", vmin=-1, vmax=1, origin=origin, extent=extent)
ax_ndwi.set_title("NDWI")
ax_ndwi.set_xlabel("Longitude")
ax_ndwi.set_ylabel("Latitude")
fig.colorbar(im, ax=ax_ndwi, shrink=0.85)

ax_mask.imshow(mask, cmap="Blues", vmin=0, vmax=1, origin=origin, extent=extent)
ax_mask.set_title(f"Water mask (NDWI > {NDWI_THRESHOLD:.2f})")
ax_mask.set_xlabel("Longitude")
ax_mask.set_ylabel("Latitude")

vals = arr[np.isfinite(arr)]
ax_hist.hist(vals, bins=80, color="gray", alpha=0.85)
ax_hist.axvline(NDWI_THRESHOLD, color="dodgerblue", linestyle="--", linewidth=2)
ax_hist.set_title("NDWI histogram")
ax_hist.set_xlabel("NDWI")
ax_hist.set_ylabel("Pixel count")

plt.tight_layout()
plt.show()

# %%
# Optional: threshold sensitivity quick-look
thresholds = [0.00, 0.05, 0.10, 0.15, 0.20]

fig, axes = plt.subplots(1, len(thresholds), figsize=(3.2 * len(thresholds), 3.5), sharex=True, sharey=True)

for ax, thr in zip(axes, thresholds):
    m = build_mask(arr, thr)
    ax.imshow(m, cmap="Blues", vmin=0, vmax=1, origin=origin, extent=extent)
    ax.set_title(f"> {thr:.2f}")
    ax.set_xlabel("Lon")

axes[0].set_ylabel("Lat")
plt.suptitle("Water mask sensitivity to NDWI threshold")
plt.tight_layout()
plt.show()
